# %%
# Importing dependencies
from IPython.display import Image, Audio
import scipy.io
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import KFold
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.metrics import mean_squared_error
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
import sklearn as sk
import seaborn as sns
import matplotlib.pyplot as plt
import mne
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Logistic regression classification of interaction with human and interaction with computer conditions

# %% [markdown]
# Successful social interactions rely on the abilities of two or more people to mutually exchange information in
# real-time, while simultaneously adapting to one another. But the underlying neural mechanisms remain unknown. In an EEG experiment, we wanted to better understand the neural mechanisms when we engage in interaction with another person, versus with a computer. We thus aimed to predict whether the brain data (recorded with EEG) originated from an experimental condition where participants engaged in interaction with another person, or with a non-responsive computer. The participants were recruited in pairs, and asked to finger tap to a given beat, which would then cease, and they would hear either the other person (interacting with human), or the computer (interaction with computer). Their task was to sycnhronize with their auditory feedback (other person or computer). The other person was thus adaptable, while the computer was not. The computer condition in this experiment was also a metronome, thus not variable. The two experimental conditions are illustrated below.

# %%
Image("conditions.png",width=700)

# %% [markdown]
# EEG data are known to be highly contaminated with noise (artefacts typically originating from muscle and eye movements). Therefore, the given EEG data are already pre-processed, and they represent the 10 Hz power estimates for each electrode (of each person in a pair) for each of the trials. The number of trials is the length of the vector $y$. Power is the squared value of the amplitude of the signal. The data contains power estimates from 60 EEG channels, where 30 belong to participant A and 30 to participant B. This gives a feature matrix $X$, with 60 columns (1 for each feature), and a length the same as the length of the vector $y$. The $y$ vector contains the labels for each trial (1 for the interaction with human condition, 0 for the interaction with computer condition). You have data from 4 pairs (features1.mat, features2.mat, features3.mat, features4.mat, and the corresponding $y$ vectors with condition labels).

# %%
# Loading features and labels
feature_mat = scipy.io.loadmat('features1.mat')

y1_mat = scipy.io.loadmat('y1.mat')

features1 = feature_mat['features1']
y1 = np.array(y1_mat['y1'].T[0])
print('The shape of the X feature matrix is: ' + str(features1.shape))
print('The shape of the y vector is: ' + str(y1.shape))

features_files = ['features1.mat', 'features2.mat', 'features3.mat', 'features4.mat']
label_files = ['y1.mat', 'y2.mat', 'y3.mat', 'y4.mat']

n_pairs = len(features_files)

features = []
labels = []

#load features and labels from all pairs
#we store them in lists, because they have different number of trials
for i,feature_f in enumerate(features_files):
    feature_map = scipy.io.loadmat(feature_f)
    y_mat = scipy.io.loadmat(label_files[i])
    idx = str(i+1)
    features.append(feature_map[f'features{idx}'])
    labels.append(np.array(y_mat[f'y{idx}'].T[0]))
    assert features[i].shape[0] == labels[i].shape[0] #ensure same n of trials and labels
# Out:
# The shape of the X feature matrix is: (1573, 60)
# The shape of the y vector is: (1573,)

# %% [markdown]
# Your task is to predict the conditions of the trials from the EEG data (10 Hz power), using a logistic regression classification. This works by fitting a general linear model with a binomial cost and a logit link function. For additional explanation about the intuition of logistic regression see this [video](https://www.youtube.com/watch?v=yIYKR4sgzI8). The logistic regression classification is fitted with a selected subset of the 60 channels (the 30 channels from each member of the pair are grouped together here). The subset of channels are chosen with sequential feature selection. A 10-fold cross validation loop needs to be implemented as well to accurately assess how well the logistic regression model with sequential feature selection performs.
#
# #### Exercise 1
# Your task is for each cross-validation fold to sequentially find the best number of features/channels and use  them to predict with the logistic regression model and calculate the training and test errors. Additionally, make sure to save the selected features in a list for later visualizations. Build-in functions for logistic regression and sequential feature selection in the scikit learn library might be helpful for your implementation.
#
# ##### The implementation step-by-step
# > * Initially let's predefine some variables. `K = 10` as we want to divide the data into 10 folds. A variable `tol = 1e-6` which is the minimum improvement to the mean squared error (MSE) required to add an additional feature. Two arrays `test_MSE` and `train_MSE` to store the MSE for training and testing in each fold. We define the cross-validation strategy from `sklearn` as `CV = KFold(K,shuffle=True)` and finally an empty list `sfs_features` is defined to save the features found with sequential feature selection.
#
# > * Now you need to set-up the cross-validation loop. Split the matrix `features1` and the vector `y1` into train and test sets using `CV.split`. For inspiration on how to do this see this [tutorial](https://riptutorial.com/scikit-learn/example/27963/k-fold-cross-validation). Furthermore, the `enumerate()` function might be helpful to keep a count variable of the fold number (e.g. `i`).
#
# > * Use `train_index` and `test_index` from `CV.split()` to index the rows designated for test and training in `features1` and `y1` respectively.
#
# > * Add an additional inner loop through the number of features (i.e. 60) and use [SequentialFeatureSelector()](https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.SequentialFeatureSelector.html) from `sklearn` to find the best features. Feed it [LogisticRegression()](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html) as estimator and set `n_features_to_select` to the loop parameter (e.g. `j`). This way you can add one feature at a time and check if it causes an improvement greater than `tol`. A boolean with the best `j` parameters is found by fitting `SequentialFeatureSelector()` to the training data and then extracted with the methods `.get_support()`.
#
# > * The logistic regression model LogisticRegression() is then fitted to the best features in the training data. This could be done as \
# `model = LogisticRegression()` \
# `model.fit(X_train[:,sfs.get_support()], y_train)` \
# where `sfs` is your `SequentialFeatureSelector()`.
#
# > * Use your logistic regression model to predict and calculate the mean squared error (MSE) using [mean_squared_error() ](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.mean_squared_error.html). Now, break the loop if the improvement in the MSE is less than the `tol` variable. If the improvement in MSE is greater than `tol` update a variable storing the best MSE. This variable should be initialized outside the inner loop as an arbitrary large number for example as `best_MSE = 1e3`.
#
# > * Lastly, save training and test MSE for each fold by using the features found with sequential feature selection. Append the boolean of the selected features to the `sfs_features` list. NB! You will need the `sfs_features` list for the exercises next week, where we will visualize and interpret the results.

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise 1: Sequential Feature Selection with Cross-Validation

# %%
# Inspect pairs: shapes and class balance
electrodes30 = ["Fp1", "Fp2", "F7", "F3", "Fz", "F4", "F8", "FC5", "FC1", "FC2", "FC6",
                "T7", "C3", "Cz", "C4", "T8", "TP9", "CP5", "CP1", "CP2", "CP6", "TP10",
                "P7", "P3", "Pz", "P4", "P8", "O1", "Oz", "O2"]

for p in range(n_pairs):
    X = features[p]
    y = labels[p]
    n_trials, n_feats = X.shape
    counts = {0: int(np.sum(y == 0)), 1: int(np.sum(y == 1))}
    print(f"Pair {p+1}: trials={n_trials}, features={n_feats}, class_counts={counts}")
    
    # Channel names (A_ = participant A, B_ = participant B)
    ch_names = [f"A_{e}" for e in electrodes30] + [f"B_{e}" for e in electrodes30]
    print(f"  example channels (0..5): {ch_names[:6]} ... last: {ch_names[-3:]}")
    print("-" * 60)
# Out:
# Pair 1: trials=1573, features=60, class_counts={0: 767, 1: 806}
#   example channels (0..5): ['A_Fp1', 'A_Fp2', 'A_F7', 'A_F3', 'A_Fz', 'A_F4'] ... last: ['B_O1', 'B_Oz', 'B_O2']
# ------------------------------------------------------------
# Pair 2: trials=1560, features=60, class_counts={0: 780, 1: 780}
#   example channels (0..5): ['A_Fp1', 'A_Fp2', 'A_F7', 'A_F3', 'A_Fz', 'A_F4'] ... last: ['B_O1', 'B_Oz', 'B_O2']
# ------------------------------------------------------------
# Pair 3: trials=1612, features=60, class_counts={0: 793, 1: 819}
#   example channels (0..5): ['A_Fp1', 'A_Fp2', 'A_F7', 'A_F3', 'A_Fz', 'A_F4'] ... last: ['B_O1', 'B_Oz', 'B_O2']
# ------------------------------------------------------------
# Pair 4: trials=1560, features=60, class_counts={0: 780, 1: 780}
#   example channels (0..5): ['A_Fp1', 'A_Fp2', 'A_F7', 'A_F3', 'A_Fz', 'A_F4'] ... last: ['B_O1', 'B_Oz', 'B_O2']
# ------------------------------------------------------------

# %%
K = 10
tol = 1e-6  # Minimum MSE improvement required to add an additional feature
test_MSE = np.zeros((n_pairs, K))
train_MSE = np.zeros((n_pairs, K))
CV = KFold(K, shuffle=True, random_state=42)  # Select Cross-validation strategy
sfs_features = [[] for x in range(n_pairs)]  # for saving the best features for each fold

# Perform CV for each pair
for p in range(n_pairs):
    X = features[p]
    y = labels[p]
    print(f"\n{'='*30}")
    print(f"Starting pair {p+1}/{n_pairs}")
    print(f"X shape: {X.shape}, y shape: {y.shape}")
    print(f"{'='*30}\n")
    
    # Cross-validation loop
    for k, (train_index, test_index) in enumerate(CV.split(X)):
        print(f"\nFold {k+1}/{K}")
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        print(f"  Training set: {X_train.shape}, Test set: {X_test.shape}")
        
        # Initial definitions - arbitrarily large test MSE + empty variable for storing results
        best_MSE = 1e3
        prev_best = best_MSE
        chosen_features = None
        mse_train_final = None
        mse_test_final = None
        
        # StandardScaler + LogisticRegression pipeline to normalize data before fitting
        pipe = Pipeline([
            ('scaler', StandardScaler()),
            ('logreg', LogisticRegression(max_iter=1000))
        ])
        
        # Sequential Feature Selection loop
        for i in range(1, X.shape[1] + 1):
            print(f"  Trying with {i} features...")
            
            # Sequential Feature Selection
            sfs = SequentialFeatureSelector(
                pipe,
                n_features_to_select=i,
                direction='forward',
                scoring='neg_mean_squared_error',
                cv=3,  # Internal cross-validation
                n_jobs=-1
            )
            sfs.fit(X_train, y_train)
            idx = sfs.get_support(indices=True)
            print(f"    Selected features so far: {list(idx)}")
            
            # Train and test with selected features
            pipe.fit(X_train[:, idx], y_train)
            
            # Use predict_proba instead of predict for smoother MSE computation
            y_train_pred = pipe.predict_proba(X_train[:, idx])[:, 1]
            y_test_pred = pipe.predict_proba(X_test[:, idx])[:, 1]
            
            mse_train = mean_squared_error(y_train, y_train_pred)
            mse_test = mean_squared_error(y_test, y_test_pred)
            print(f"    MSE (train/test): {mse_train:.6f} / {mse_test:.6f}")
            
            # Check if the MSE improved enough to add this feature
            improvement = prev_best - mse_test
            if improvement >= tol:
                print(f"    Improvement found ({improvement:.2e} >= tol={tol}) keeping feature set")
                prev_best = mse_test
                best_MSE = mse_test
                chosen_features = idx
                mse_train_final = mse_train
                mse_test_final = mse_test
            else:
                print(f"    No significant improvement ({improvement:.2e} < tol={tol}) stopping selection")
                # Stop if no significant improvement
                break
        
        # Handle edge case: if no improvement was detected at all
        if mse_test_final is None:
            print("  No improvement detected at all; using last feature set.")
            mse_test_final = best_MSE
            mse_train_final = mse_train
            chosen_features = idx
        
        test_MSE[p, k] = mse_test_final
        train_MSE[p, k] = mse_train_final
        sfs_features[p].append(chosen_features)
        
        print(f"\n  Fold {k+1} finished.")
        print(f"  Best MSE (test): {mse_test_final:.6f}")
        print(f"  Selected features: {list(chosen_features)}")
    
    print(f"\nPair {p+1} completed.")
    print(f"Average test MSE across folds: {np.mean(test_MSE[p]):.6f}")
    print(f"Average number of selected features: {np.mean([len(f) for f in sfs_features[p]]):.2f}")
    print("-" * 63)
# Out:
# ==============================
# Starting pair 1/4
# X shape: (1573, 60), y shape: (1573,)
# ==============================
#
#
# Fold 1/10
#   Training set: (1415, 60), Test set: (158, 60)
#   Trying with 1 features...
#     Selected features so far: [41]
#     MSE (train/test): 0.145453 / 0.138291
#     Improvement found (1.00e+03 >= tol=1e-06) keeping feature set
#   Trying with 2 features...
#     Selected features so far: [32, 41]
#     MSE (train/test): 0.111812 / 0.107882
#     Improvement found (3.04e-02 >= tol=1e-06) keeping feature set
#   Trying with 3 features...
#     Selected features so far: [32, 36, 41]
#     MSE (train/test): 0.096656 / 0.080311
#     Improvement found (2.76e-02 >= tol=1e-06) keeping feature set
#   Trying with 4 features...
#     Selected features so far: [32, 33, 36, 41]
#     MSE (train/test): 0.086436 / 0.075585
#     Improvement found (4.73e-03 >= tol=1e-06) keeping feature set
#   Trying with 5 features...
#     Selected features so far: [32, 33, 36, 41, 55]
#     MSE (train/test): 0.082563 / 0.074369
#     Improvement found (1.22e-03 >= tol=1e-06) keeping feature set
#   Trying with 6 features...
#     Selected features so far: [32, 33, 36, 41, 54, 55]
#     MSE (train/test): 0.080369 / 0.070751
#     Improvement found (3.62e-03 >= tol=1e-06) keeping feature set
#   Trying with 7 features...
#     Selected features so far: [32, 33, 36, 41, 54, 55, 58]
#     MSE (train/test): 0.080301 / 0.070227
#     Improvement found (5.24e-04 >= tol=1e-06) keeping feature set
#   Trying with 8 features...
#     Selected features so far: [32, 33, 36, 41, 54, 55, 57, 58]
#     MSE (train/test): 0.080264 / 0.070189
#     Improvement found (3.75e-05 >= tol=1e-06) keeping feature set
#   Trying with 9 features...
#     Selected features so far: [32, 33, 36, 39, 41, 54, 55, 57, 58]
#     MSE (train/test): 0.080299 / 0.070363
#     No significant improvement (-1.74e-04 < tol=1e-06) stopping selection
#
#   Fold 1 finished.
#   Best MSE (test): 0.070189
#   Selected features: [32, 33, 36, 41, 54, 55, 57, 58]
#
# Fold 2/10
#   Training set: (1415, 60), Test set: (158, 60)
#   Trying with 1 features...
#     Selected features so far: [41]
#     MSE (train/test): 0.142884 / 0.161879
#     Improvement found (1.00e+03 >= tol=1e-06) keeping feature set
#   Trying with 2 features...
#     Selected features so far: [32, 41]
#     MSE (train/test): 0.109373 / 0.129738
#     Improvement found (3.21e-02 >= tol=1e-06) keeping feature set
#   Trying with 3 features...
#     Selected features so far: [32, 36, 41]
#     MSE (train/test): 0.094302 / 0.101237
#     Improvement found (2.85e-02 >= tol=1e-06) keeping feature set
#   Trying with 4 features...
#     Selected features so far: [32, 33, 36, 41]
#     MSE (train/test): 0.083801 / 0.098663
#     Improvement found (2.57e-03 >= tol=1e-06) keeping feature set
#   Trying with 5 features...
#     Selected features so far: [32, 33, 36, 41, 55]
#     MSE (train/test): 0.081132 / 0.088042
#     Improvement found (1.06e-02 >= tol=1e-06) keeping feature set
#   Trying with 6 features...
#     Selected features so far: [7, 32, 33, 36, 41, 55]
#     MSE (train/test): 0.078372 / 0.087004
#     Improvement found (1.04e-03 >= tol=1e-06) keeping feature set
#   Trying with 7 features...
#     Selected features so far: [7, 19, 32, 33, 36, 41, 55]
#     MSE (train/test): 0.077495 / 0.083827
#     Improvement found (3.18e-03 >= tol=1e-06) keeping feature set
#   Trying with 8 features...
#     Selected features so far: [7, 16, 19, 32, 33, 36, 41, 55]
#     MSE (train/test): 0.077122 / 0.085126
#     No significant improvement (-1.30e-03 < tol=1e-06) stopping selection
#
#   Fold 2 finished.
#   Best MSE (test): 0.083827
#   Selected features: [7, 19, 32, 33, 36, 41, 55]
#
# Fold 3/10
#   Training set: (1415, 60), Test set: (158, 60)
#   Trying with 1 features...
#     Selected features so far: [41]
#     MSE (train/test): 0.144986 / 0.145403
#     Improvement found (1.00e+03 >= tol=1e-06) keeping feature set
#   Trying with 2 features...
#     Selected features so far: [32, 41]
#     MSE (train/test): 0.110966 / 0.118050
#     Improvement found (2.74e-02 >= tol=1e-06) keeping feature set
#   Trying with 3 features...
#     Selected features so far: [32, 36, 41]
#     MSE (train/test): 0.095287 / 0.095489
#     Improvement found (2.26e-02 >= tol=1e-06) keeping feature set
#   Trying with 4 features...
#     Selected features so far: [32, 33, 36, 41]
#     MSE (train/test): 0.085880 / 0.083253
#     Improvement found (1.22e-02 >= tol=1e-06) keeping feature set
#   Trying with 5 features...
#     Selected features so far: [32, 33, 36, 41, 54]
#     MSE (train/test): 0.080977 / 0.088064
#     No significant improvement (-4.81e-03 < tol=1e-06) stopping selection
#
#   Fold 3 finished.
#   Best MSE (test): 0.083253
#   Selected features: [32, 33, 36, 41]
#
# Fold 4/10
#   Training set: (1416, 60), Test set: (157, 60)
#   Trying with 1 features...
#     Selected features so far: [41]
#     MSE (train/test): 0.147272 / 0.121797
#     Improvement found (1.00e+03 >= tol=1e-06) keeping feature set
#   Trying with 2 features...
#     Selected features so far: [32, 41]
#     MSE (train/test): 0.113136 / 0.094605
#     Improvement found (2.72e-02 >= tol=1e-06) keeping feature set
#   Trying with 3 features...
#     Selected features so far: [32, 36, 41]
#     MSE (train/test): 0.095115 / 0.093282
#     Improvement found (1.32e-03 >= tol=1e-06) keeping feature set
#   Trying with 4 features...
#     Selected features so far: [32, 33, 36, 41]
#     MSE (train/test): 0.084160 / 0.094439
#     No significant improvement (-1.16e-03 < tol=1e-06) stopping selection
#
#   Fold 4 finished.
#   Best MSE (test): 0.093282
#   Selected features: [32, 36, 41]
#
# Fold 5/10
#   Training set: (1416, 60), Test set: (157, 60)
#   Trying with 1 features...
#     Selected features so far: [41]
#     MSE (train/test): 0.144674 / 0.144808
#     Improvement found (1.00e+03 >= tol=1e-06) keeping feature set
#   Trying with 2 features...
#     Selected features so far: [32, 41]
#     MSE (train/test): 0.110167 / 0.121224
#     Improvement found (2.36e-02 >= tol=1e-06) keeping feature set
#   Trying with 3 features...
#     Selected features so far: [32, 37, 41]
#     MSE (train/test): 0.096287 / 0.109430
#     Improvement found (1.18e-02 >= tol=1e-06) keeping feature set
#   Trying with 4 features...
#     Selected features so far: [32, 36, 37, 41]
#     MSE (train/test): 0.083883 / 0.092470
#     Improvement found (1.70e-02 >= tol=1e-06) keeping feature set
#   Trying with 5 features...
#     Selected features so far: [32, 33, 36, 37, 41]
#     MSE (train/test): 0.076163 / 0.081745
#     Improvement found (1.07e-02 >= tol=1e-06) keeping feature set
#   Trying with 6 features...
#     Selected features so far: [31, 32, 33, 36, 37, 41]
#     MSE (train/test): 0.072549 / 0.077961
#     Improvement found (3.78e-03 >= tol=1e-06) keeping feature set
#   Trying with 7 features...
#     Selected features so far: [31, 32, 33, 36, 37, 41, 54]
#     MSE (train/test): 0.071025 / 0.075926
#     Improvement found (2.03e-03 >= tol=1e-06) keeping feature set
#   Trying with 8 features...
#     Selected features so far: [30, 31, 32, 33, 36, 37, 41, 54]
#     MSE (train/test): 0.070543 / 0.076420
#     No significant improvement (-4.94e-04 < tol=1e-06) stopping selection
#
#   Fold 5 finished.
#   Best MSE (test): 0.075926
#   Selected features: [31, 32, 33, 36, 37, 41, 54]
#
# Fold 6/10
#   Training set: (1416, 60), Test set: (157, 60)
#   Trying with 1 features...
#     Selected features so far: [41]
#     MSE (train/test): 0.142969 / 0.162231
#     Improvement found (1.00e+03 >= tol=1e-06) keeping feature set
#   Trying with 2 features...
#     Selected features so far: [32, 41]
#     MSE (train/test): 0.110015 / 0.123383
#     Improvement found (3.88e-02 >= tol=1e-06) keeping feature set
#   Trying with 3 features...
#     Selected features so far: [32, 36, 41]
#     MSE (train/test): 0.093297 / 0.109407
#     Improvement found (1.40e-02 >= tol=1e-06) keeping feature set
#   Trying with 4 features...
#     Selected features so far: [31, 32, 36, 41]
#     MSE (train/test): 0.085656 / 0.103112
#     Improvement found (6.30e-03 >= tol=1e-06) keeping feature set
#   Trying with 5 features...
#     Selected features so far: [31, 32, 36, 41, 55]
#     MSE (train/test): 0.082300 / 0.100760
#     Improvement found (2.35e-03 >= tol=1e-06) keeping feature set
#   Trying with 6 features...
#     Selected features so far: [31, 32, 36, 38, 41, 55]
#     MSE (train/test): 0.082080 / 0.100361
#     Improvement found (3.99e-04 >= tol=1e-06) keeping feature set
#   Trying with 7 features...
#     Selected features so far: [31, 32, 35, 36, 38, 41, 55]
#     MSE (train/test): 0.081907 / 0.100073
#     Improvement found (2.88e-04 >= tol=1e-06) keeping feature set
#   Trying with 8 features...
#     Selected features so far: [31, 32, 35, 36, 38, 41, 51, 55]
#     MSE (train/test): 0.081914 / 0.100108
#     No significant improvement (-3.48e-05 < tol=1e-06) stopping selection
#
#   Fold 6 finished.
#   Best MSE (test): 0.100073
#   Selected features: [31, 32, 35, 36, 38, 41, 55]
#
# Fold 7/10
#   Training set: (1416, 60), Test set: (157, 60)
#   Trying with 1 features...
#     Selected features so far: [41]
#     MSE (train/test): 0.144857 / 0.144495
#     Improvement found (1.00e+03 >= tol=1e-06) keeping feature set
#   Trying with 2 features...
#     Selected features so far: [32, 41]
#     MSE (train/test): 0.113925 / 0.088600
#     Improvement found (5.59e-02 >= tol=1e-06) keeping feature set
#   Trying with 3 features...
#     Selected features so far: [32, 36, 41]
#     MSE (train/test): 0.095686 / 0.087553
#     Improvement found (1.05e-03 >= tol=1e-06) keeping feature set
#   Trying with 4 features...
#     Selected features so far: [32, 33, 36, 41]
#     MSE (train/test): 0.086226 / 0.074922
#     Improvement found (1.26e-02 >= tol=1e-06) keeping feature set
#   Trying with 5 features...
#     Selected features so far: [30, 32, 33, 36, 41]
#     MSE (train/test): 0.084231 / 0.073100
#     Improvement found (1.82e-03 >= tol=1e-06) keeping feature set
#   Trying with 6 features...
#     Selected features so far: [17, 30, 32, 33, 36, 41]
#     MSE (train/test): 0.084184 / 0.073044
#     Improvement found (5.53e-05 >= tol=1e-06) keeping feature set
#   Trying with 7 features...
#     Selected features so far: [17, 30, 32, 33, 36, 39, 41]
#     MSE (train/test): 0.084114 / 0.072973
#     Improvement found (7.12e-05 >= tol=1e-06) keeping feature set
#   Trying with 8 features...
#     Selected features so far: [17, 30, 32, 33, 36, 39, 41, 46]
#     MSE (train/test): 0.084117 / 0.073084
#     No significant improvement (-1.11e-04 < tol=1e-06) stopping selection
#
#   Fold 7 finished.
#   Best MSE (test): 0.072973
#   Selected features: [17, 30, 32, 33, 36, 39, 41]
#
# Fold 8/10
#   Training set: (1416, 60), Test set: (157, 60)
#   Trying with 1 features...
#     Selected features so far: [41]
#     MSE (train/test): 0.143692 / 0.156150
#     Improvement found (1.00e+03 >= tol=1e-06) keeping feature set
#   Trying with 2 features...
#     Selected features so far: [32, 41]
#     MSE (train/test): 0.110258 / 0.122160
#     Improvement found (3.40e-02 >= tol=1e-06) keeping feature set
#   Trying with 3 features...
#     Selected features so far: [32, 36, 41]
#     MSE (train/test): 0.095223 / 0.092312
#     Improvement found (2.98e-02 >= tol=1e-06) keeping feature set
#   Trying with 4 features...
#     Selected features so far: [32, 33, 36, 41]
#     MSE (train/test): 0.085787 / 0.081424
#     Improvement found (1.09e-02 >= tol=1e-06) keeping feature set
#   Trying with 5 features...
#     Selected features so far: [30, 32, 33, 36, 41]
#     MSE (train/test): 0.084063 / 0.076394
#     Improvement found (5.03e-03 >= tol=1e-06) keeping feature set
#   Trying with 6 features...
#     Selected features so far: [30, 32, 33, 36, 41, 53]
#     MSE (train/test): 0.083435 / 0.075508
#     Improvement found (8.86e-04 >= tol=1e-06) keeping feature set
#   Trying with 7 features...
#     Selected features so far: [30, 32, 33, 36, 41, 43, 53]
#     MSE (train/test): 0.083392 / 0.074775
#     Improvement found (7.33e-04 >= tol=1e-06) keeping feature set
#   Trying with 8 features...
#     Selected features so far: [17, 30, 32, 33, 36, 41, 43, 53]
#     MSE (train/test): 0.083289 / 0.074826
#     No significant improvement (-5.05e-05 < tol=1e-06) stopping selection
#
#   Fold 8 finished.
#   Best MSE (test): 0.074775
#   Selected features: [30, 32, 33, 36, 41, 43, 53]
#
# Fold 9/10
#   Training set: (1416, 60), Test set: (157, 60)
#   Trying with 1 features...
#     Selected features so far: [41]
#     MSE (train/test): 0.148716 / 0.112118
#     Improvement found (1.00e+03 >= tol=1e-06) keeping feature set
#   Trying with 2 features...
#     Selected features so far: [32, 41]
#     MSE (train/test): 0.115403 / 0.078333
#     Improvement found (3.38e-02 >= tol=1e-06) keeping feature set
#   Trying with 3 features...
#     Selected features so far: [32, 37, 41]
#     MSE (train/test): 0.100292 / 0.076463
#     Improvement found (1.87e-03 >= tol=1e-06) keeping feature set
#   Trying with 4 features...
#     Selected features so far: [32, 36, 37, 41]
#     MSE (train/test): 0.087333 / 0.065826
#     Improvement found (1.06e-02 >= tol=1e-06) keeping feature set
#   Trying with 5 features...
#     Selected features so far: [32, 33, 36, 37, 41]
#     MSE (train/test): 0.078754 / 0.061569
#     Improvement found (4.26e-03 >= tol=1e-06) keeping feature set
#   Trying with 6 features...
#     Selected features so far: [31, 32, 33, 36, 37, 41]
#     MSE (train/test): 0.075181 / 0.058406
#     Improvement found (3.16e-03 >= tol=1e-06) keeping feature set
#   Trying with 7 features...
#     Selected features so far: [31, 32, 33, 36, 37, 41, 54]
#     MSE (train/test): 0.073858 / 0.055601
#     Improvement found (2.80e-03 >= tol=1e-06) keeping feature set
#   Trying with 8 features...
#     Selected features so far: [3, 31, 32, 33, 36, 37, 41, 54]
#     MSE (train/test): 0.073823 / 0.054861
#     Improvement found (7.41e-04 >= tol=1e-06) keeping feature set
#   Trying with 9 features...
#     Selected features so far: [3, 31, 32, 33, 36, 37, 41, 51, 54]
#     MSE (train/test): 0.073660 / 0.054485
#     Improvement found (3.76e-04 >= tol=1e-06) keeping feature set
#   Trying with 10 features...
#     Selected features so far: [3, 13, 31, 32, 33, 36, 37, 41, 51, 54]
#     MSE (train/test): 0.073589 / 0.054734
#     No significant improvement (-2.48e-04 < tol=1e-06) stopping selection
#
#   Fold 9 finished.
#   Best MSE (test): 0.054485
#   Selected features: [3, 31, 32, 33, 36, 37, 41, 51, 54]
#
# Fold 10/10
#   Training set: (1416, 60), Test set: (157, 60)
#   Trying with 1 features...
#     Selected features so far: [41]
#     MSE (train/test): 0.142305 / 0.167431
#     Improvement found (1.00e+03 >= tol=1e-06) keeping feature set
#   Trying with 2 features...
#     Selected features so far: [32, 41]
#     MSE (train/test): 0.108566 / 0.136103
#     Improvement found (3.13e-02 >= tol=1e-06) keeping feature set
#   Trying with 3 features...
#     Selected features so far: [32, 36, 41]
#     MSE (train/test): 0.091304 / 0.125257
#     Improvement found (1.08e-02 >= tol=1e-06) keeping feature set
#   Trying with 4 features...
#     Selected features so far: [32, 33, 36, 41]
#     MSE (train/test): 0.082950 / 0.103657
#     Improvement found (2.16e-02 >= tol=1e-06) keeping feature set
#   Trying with 5 features...
#     Selected features so far: [30, 32, 33, 36, 41]
#     MSE (train/test): 0.080882 / 0.101210
#     Improvement found (2.45e-03 >= tol=1e-06) keeping feature set
#   Trying with 6 features...
#     Selected features so far: [30, 32, 33, 36, 41, 53]
#     MSE (train/test): 0.080103 / 0.100884
#     Improvement found (3.26e-04 >= tol=1e-06) keeping feature set
#   Trying with 7 features...
#     Selected features so far: [28, 30, 32, 33, 36, 41, 53]
#     MSE (train/test): 0.078214 / 0.100485
#     Improvement found (3.99e-04 >= tol=1e-06) keeping feature set
#   Trying with 8 features...
#     Selected features so far: [28, 30, 32, 33, 35, 36, 41, 53]
#     MSE (train/test): 0.077608 / 0.098723
#     Improvement found (1.76e-03 >= tol=1e-06) keeping feature set
#   Trying with 9 features...
#     Selected features so far: [28, 30, 32, 33, 35, 36, 41, 49, 53]
#     MSE (train/test): 0.077147 / 0.097999
#     Improvement found (7.24e-04 >= tol=1e-06) keeping feature set
#   Trying with 10 features...
#     Selected features so far: [9, 28, 30, 32, 33, 35, 36, 41, 49, 53]
#     MSE (train/test): 0.076214 / 0.097204
#     Improvement found (7.95e-04 >= tol=1e-06) keeping feature set
#   Trying with 11 features...
#     Selected features so far: [9, 28, 30, 32, 33, 35, 36, 41, 45, 49, 53]
#     MSE (train/test): 0.076041 / 0.097865
#     No significant improvement (-6.61e-04 < tol=1e-06) stopping selection
#
#   Fold 10 finished.
#   Best MSE (test): 0.097204
#   Selected features: [9, 28, 30, 32, 33, 35, 36, 41, 49, 53]
#
# Pair 1 completed.
# Average test MSE across folds: 0.080599
# Average number of selected features: 6.90
# ---------------------------------------------------------------
#
# ==============================
# Starting pair 2/4
# X shape: (1560, 60), y shape: (1560,)
# ==============================
#
#
# Fold 1/10
#   Training set: (1404, 60), Test set: (156, 60)
#   Trying with 1 features...
#     Selected features so far: [2]
#     MSE (train/test): 0.198131 / 0.205638
#     Improvement found (1.00e+03 >= tol=1e-06) keeping feature set
#   Trying with 2 features...
#     Selected features so far: [2, 5]
#     MSE (train/test): 0.171463 / 0.182560
#     Improvement found (2.31e-02 >= tol=1e-06) keeping feature set
#   Trying with 3 features...
#     Selected features so far: [1, 2, 5]
#     MSE (train/test): 0.146151 / 0.150975
#     Improvement found (3.16e-02 >= tol=1e-06) keeping feature set
#   Trying with 4 features...
#     Selected features so far: [1, 2, 5, 10]
#     MSE (train/test): 0.129592 / 0.145730
#     Improvement found (5.24e-03 >= tol=1e-06) keeping feature set
#   Trying with 5 features...
#     Selected features so far: [1, 2, 5, 9, 10]
#     MSE (train/test): 0.121086 / 0.134702
#     Improvement found (1.10e-02 >= tol=1e-06) keeping feature set
#   Trying with 6 features...
#     Selected features so far: [0, 1, 2, 5, 9, 10]
#     MSE (train/test): 0.112428 / 0.121069
#     Improvement found (1.36e-02 >= tol=1e-06) keeping feature set
#   Trying with 7 features...
#     Selected features so far: [0, 1, 2, 5, 9, 10, 22]
#     MSE (train/test): 0.105836 / 0.121955
#     No significant improvement (-8.86e-04 < tol=1e-06) stopping selection
#
#   Fold 1 finished.
#   Best MSE (test): 0.121069
#   Selected features: [0, 1, 2, 5, 9, 10]
#
# Fold 2/10
#   Training set: (1404, 60), Test set: (156, 60)
#   Trying with 1 features...
#     Selected features so far: [2]
#     MSE (train/test): 0.200748 / 0.182412
#     Improvement found (1.00e+03 >= tol=1e-06) keeping feature set
#   Trying with 2 features...
#     Selected features so far: [2, 5]
#     MSE (train/test): 0.174762 / 0.154566
#     Improvement found (2.78e-02 >= tol=1e-06) keeping feature set
#   Trying with 3 features...
#     Selected features so far: [1, 2, 5]
#     MSE (train/test): 0.149827 / 0.119549
#     Improvement found (3.50e-02 >= tol=1e-06) keeping feature set
#   Trying with 4 features...
#     Selected features so far: [1, 2, 5, 10]
#     MSE (train/test): 0.133562 / 0.110383
#     Improvement found (9.17e-03 >= tol=1e-06) keeping feature set
#   Trying with 5 features...
#     Selected features so far: [1, 2, 5, 10, 22]
#     MSE (train/test): 0.124053 / 0.107489
#     Improvement found (2.89e-03 >= tol=1e-06) keeping feature set
#   Trying with 6 features...
#     Selected features so far: [1, 2, 5, 10, 22, 28]
#     MSE (train/test): 0.121573 / 0.107929
#     No significant improvement (-4.41e-04 < tol=1e-06) stopping selection
#
#   Fold 2 finished.
#   Best MSE (test): 0.107489
#   Selected features: [1, 2, 5, 10, 22]
#
# Fold 3/10
#   Training set: (1404, 60), Test set: (156, 60)
#   Trying with 1 features...
#     Selected features so far: [2]
#     MSE (train/test): 0.198358 / 0.203251
#     Improvement found (1.00e+03 >= tol=1e-06) keeping feature set
#   Trying with 2 features...
#     Selected features so far: [2, 5]
#     MSE (train/test): 0.171891 / 0.176463
#     Improvement found (2.68e-02 >= tol=1e-06) keeping feature set
#   Trying with 3 features...
#     Selected features so far: [1, 2, 5]
#     MSE (train/test): 0.145870 / 0.151927
#     Improvement found (2.45e-02 >= tol=1e-06) keeping feature set
#   Trying with 4 features...
#     Selected features so far: [1, 2, 5, 10]
#     MSE (train/test): 0.129755 / 0.142504
#     Improvement found (9.42e-03 >= tol=1e-06) keeping feature set
#   Trying with 5 features...
#     Selected features so far: [1, 2, 5, 10, 22]
#     MSE (train/test): 0.120346 / 0.138350
#     Improvement found (4.15e-03 >= tol=1e-06) keeping feature set
#   Trying with 6 features...
#     Selected features so far: [1, 2, 5, 10, 22, 44]
#     MSE (train/test): 0.115327 / 0.131844
#     Improvement found (6.51e-03 >= tol=1e-06) keeping feature set
#   Trying with 7 features...
#     Selected features so far: [0, 1, 2, 5, 10, 22, 44]
#     MSE (train/test): 0.109107 / 0.119489
#     Improvement found (1.24e-02 >= tol=1e-06) keeping feature set
#   Trying with 8 features...
#     Selected features so far: [0, 1, 2, 5, 9, 10, 22, 44]
#     MSE (train/test): 0.099327 / 0.125475
#     No significant improvement (-5.99e-03 < tol=1e-06) stopping selection
#
#   Fold 3 finished.
#   Best MSE (test): 0.119489
#   Selected features: [0, 1, 2, 5, 10, 22, 44]
#
# Fold 4/10
#   Training set: (1404, 60), Test set: (156, 60)
#   Trying with 1 features...
#     Selected features so far: [2]
#     MSE (train/test): 0.197113 / 0.215097
#     Improvement found (1.00e+03 >= tol=1e-06) keeping feature set
#   Trying with 2 features...
#     Selected features so far: [2, 5]
#     MSE (train/test): 0.171339 / 0.184054
#     Improvement found (3.10e-02 >= tol=1e-06) keeping feature set
#   Trying with 3 features...
#     Selected features so far: [1, 2, 5]
#     MSE (train/test): 0.146532 / 0.147711
#     Improvement found (3.63e-02 >= tol=1e-06) keeping feature set
#   Trying with 4 features...
#     Selected features so far: [1, 2, 5, 10]
#     MSE (train/test): 0.132411 / 0.120587
#     Improvement found (2.71e-02 >= tol=1e-06) keeping feature set
#   Trying with 5 features...
#     Selected features so far: [1, 2, 5, 10, 22]
#     MSE (train/test): 0.124481 / 0.102615
#     Improvement found (1.80e-02 >= tol=1e-06) keeping feature set
#   Trying with 6 features...
#     Selected features so far: [1, 2, 5, 10, 22, 50]
#     MSE (train/test): 0.122353 / 0.102722
#     No significant improvement (-1.07e-04 < tol=1e-06) stopping selection
#
#   Fold 4 finished.
#   Best MSE (test): 0.102615
#   Selected features: [1, 2, 5, 10, 22]
#
# Fold 5/10
#   Training set: (1404, 60), Test set: (156, 60)
#   Trying with 1 features...
#     Selected features so far: [2]
#     MSE (train/test): 0.198941 / 0.198984
#     Improvement found (1.00e+03 >= tol=1e-06) keeping feature set
#   Trying with 2 features...
#     Selected features so far: [2, 5]
#     MSE (train/test): 0.173302 / 0.167512
#     Improvement found (3.15e-02 >= tol=1e-06) keeping feature set
#   Trying with 3 features...
#     Selected features so far: [1, 2, 5]
#     MSE (train/test): 0.143901 / 0.172665
#     No significant improvement (-5.15e-03 < tol=1e-06) stopping selection
#
#   Fold 5 finished.
#   Best MSE (test): 0.167512
#   Selected features: [2, 5]
#
# Fold 6/10
#   Training set: (1404, 60), Test set: (156, 60)
#   Trying with 1 features...
#     Selected features so far: [2]
#     MSE (train/test): 0.199919 / 0.189391
#     Improvement found (1.00e+03 >= tol=1e-06) keeping feature set
#   Trying with 2 features...
#     Selected features so far: [2, 5]
#     MSE (train/test): 0.174035 / 0.160347
#     Improvement found (2.90e-02 >= tol=1e-06) keeping feature set
#   Trying with 3 features...
#     Selected features so far: [1, 2, 5]
#     MSE (train/test): 0.147654 / 0.137297
#     Improvement found (2.30e-02 >= tol=1e-06) keeping feature set
#   Trying with 4 features...
#     Selected features so far: [1, 2, 5, 10]
#     MSE (train/test): 0.131911 / 0.125408
#     Improvement found (1.19e-02 >= tol=1e-06) keeping feature set
#   Trying with 5 features...
#     Selected features so far: [1, 2, 5, 10, 22]
#     MSE (train/test): 0.123323 / 0.113715
#     Improvement found (1.17e-02 >= tol=1e-06) keeping feature set
#   Trying with 6 features...
#     Selected features so far: [1, 2, 5, 10, 22, 44]
#     MSE (train/test): 0.118128 / 0.109082
#     Improvement found (4.63e-03 >= tol=1e-06) keeping feature set
#   Trying with 7 features...
#     Selected features so far: [1, 2, 5, 10, 16, 22, 44]
#     MSE (train/test): 0.114341 / 0.105456
#     Improvement found (3.63e-03 >= tol=1e-06) keeping feature set
#   Trying with 8 features...
#     Selected features so far: [0, 1, 2, 5, 10, 16, 22, 44]
#     MSE (train/test): 0.107014 / 0.094487
#     Improvement found (1.10e-02 >= tol=1e-06) keeping feature set
#   Trying with 9 features...
#     Selected features so far: [0, 1, 2, 5, 9, 10, 16, 22, 44]
#     MSE (train/test): 0.099868 / 0.082162
#     Improvement found (1.23e-02 >= tol=1e-06) keeping feature set
#   Trying with 10 features...
#     Selected features so far: [0, 1, 2, 5, 9, 10, 16, 22, 27, 44]
#     MSE (train/test): 0.098763 / 0.078891
#     Improvement found (3.27e-03 >= tol=1e-06) keeping feature set
#   Trying with 11 features...
#     Selected features so far: [0, 1, 2, 5, 9, 10, 16, 22, 27, 44, 58]
#     MSE (train/test): 0.098859 / 0.078203
#     Improvement found (6.87e-04 >= tol=1e-06) keeping feature set
#   Trying with 12 features...
#     Selected features so far: [0, 1, 2, 5, 9, 10, 12, 16, 22, 27, 44, 58]
#     MSE (train/test): 0.098846 / 0.078794
#     No significant improvement (-5.90e-04 < tol=1e-06) stopping selection
#
#   Fold 6 finished.
#   Best MSE (test): 0.078203
#   Selected features: [0, 1, 2, 5, 9, 10, 16, 22, 27, 44, 58]
#
# Fold 7/10
#   Training set: (1404, 60), Test set: (156, 60)
#   Trying with 1 features...
#     Selected features so far: [2]
#     MSE (train/test): 0.199195 / 0.196762
#     Improvement found (1.00e+03 >= tol=1e-06) keeping feature set
#   Trying with 2 features...
#     Selected features so far: [2, 5]
#     MSE (train/test): 0.172581 / 0.174940
#     Improvement found (2.18e-02 >= tol=1e-06) keeping feature set
#   Trying with 3 features...
#     Selected features so far: [1, 2, 5]
#     MSE (train/test): 0.146170 / 0.151356
#     Improvement found (2.36e-02 >= tol=1e-06) keeping feature set
#   Trying with 4 features...
#     Selected features so far: [1, 2, 5, 10]
#     MSE (train/test): 0.131671 / 0.127704
#     Improvement found (2.37e-02 >= tol=1e-06) keeping feature set
#   Trying with 5 features...
#     Selected features so far: [1, 2, 5, 10, 22]
#     MSE (train/test): 0.123099 / 0.116198
#     Improvement found (1.15e-02 >= tol=1e-06) keeping feature set
#   Trying with 6 features...
#     Selected features so far: [1, 2, 5, 9, 10, 22]
#     MSE (train/test): 0.117028 / 0.109767
#     Improvement found (6.43e-03 >= tol=1e-06) keeping feature set
#   Trying with 7 features...
#     Selected features so far: [0, 1, 2, 5, 9, 10, 22]
#     MSE (train/test): 0.108005 / 0.103117
#     Improvement found (6.65e-03 >= tol=1e-06) keeping feature set
#   Trying with 8 features...
#     Selected features so far: [0, 1, 2, 5, 9, 10, 22, 40]
#     MSE (train/test): 0.103343 / 0.097044
#     Improvement found (6.07e-03 >= tol=1e-06) keeping feature set
#   Trying with 9 features...
#     Selected features so far: [0, 1, 2, 5, 9, 10, 16, 22, 40]
#     MSE (train/test): 0.098445 / 0.096585
#     Improvement found (4.60e-04 >= tol=1e-06) keeping feature set
#   Trying with 10 features...
#     Selected features so far: [0, 1, 2, 5, 9, 10, 16, 22, 40, 47]
#     MSE (train/test): 0.098099 / 0.096853
#     No significant improvement (-2.68e-04 < tol=1e-06) stopping selection
#
#   Fold 7 finished.
#   Best MSE (test): 0.096585
#   Selected features: [0, 1, 2, 5, 9, 10, 16, 22, 40]
#
# Fold 8/10
#   Training set: (1404, 60), Test set: (156, 60)
#   Trying with 1 features...
#     Selected features so far: [2]
#     MSE (train/test): 0.197496 / 0.210915
#     Improvement found (1.00e+03 >= tol=1e-06) keeping feature set
#   Trying with 2 features...
#     Selected features so far: [2, 5]
#     MSE (train/test): 0.171302 / 0.182763
#     Improvement found (2.82e-02 >= tol=1e-06) keeping feature set
#   Trying with 3 features...
#     Selected features so far: [1, 2, 5]
#     MSE (train/test): 0.146419 / 0.148259
#     Improvement found (3.45e-02 >= tol=1e-06) keeping feature set
#   Trying with 4 features...
#     Selected features so far: [1, 2, 5, 10]
#     MSE (train/test): 0.130227 / 0.140089
#     Improvement found (8.17e-03 >= tol=1e-06) keeping feature set
#   Trying with 5 features...
#     Selected features so far: [1, 2, 5, 10, 40]
#     MSE (train/test): 0.125209 / 0.141372
#     No significant improvement (-1.28e-03 < tol=1e-06) stopping selection
#
#   Fold 8 finished.
#   Best MSE (test): 0.140089
#   Selected features: [1, 2, 5, 10]
#
# Fold 9/10
#   Training set: (1404, 60), Test set: (156, 60)
#   Trying with 1 features...
#     Selected features so far: [2]
#     MSE (train/test): 0.199784 / 0.190400
#     Improvement found (1.00e+03 >= tol=1e-06) keeping feature set
#   Trying with 2 features...
#     Selected features so far: [2, 5]
#     MSE (train/test): 0.172737 / 0.169880
#     Improvement found (2.05e-02 >= tol=1e-06) keeping feature set
#   Trying with 3 features...
#     Selected features so far: [1, 2, 5]
#     MSE (train/test): 0.147049 / 0.142264
#     Improvement found (2.76e-02 >= tol=1e-06) keeping feature set
#   Trying with 4 features...
#     Selected features so far: [1, 2, 5, 10]
#     MSE (train/test): 0.132643 / 0.117940
#     Improvement found (2.43e-02 >= tol=1e-06) keeping feature set
#   Trying with 5 features...
#     Selected features so far: [0, 1, 2, 5, 10]
#     MSE (train/test): 0.122406 / 0.131540
#     No significant improvement (-1.36e-02 < tol=1e-06) stopping selection
#
#   Fold 9 finished.
#   Best MSE (test): 0.117940
#   Selected features: [1, 2, 5, 10]
#
# Fold 10/10
#   Training set: (1404, 60), Test set: (156, 60)
#   Trying with 1 features...
#     Selected features so far: [2]
#     MSE (train/test): 0.198676 / 0.200721
#     Improvement found (1.00e+03 >= tol=1e-06) keeping feature set
#   Trying with 2 features...
#     Selected features so far: [2, 5]
#     MSE (train/test): 0.171966 / 0.178994
#     Improvement found (2.17e-02 >= tol=1e-06) keeping feature set
#   Trying with 3 features...
#     Selected features so far: [1, 2, 5]
#     MSE (train/test): 0.146273 / 0.149956
#     Improvement found (2.90e-02 >= tol=1e-06) keeping feature set
#   Trying with 4 features...
#     Selected features so far: [1, 2, 5, 10]
#     MSE (train/test): 0.130238 / 0.140133
#     Improvement found (9.82e-03 >= tol=1e-06) keeping feature set
#   Trying with 5 features...
#     Selected features so far: [1, 2, 5, 10, 22]
#     MSE (train/test): 0.121539 / 0.129202
#     Improvement found (1.09e-02 >= tol=1e-06) keeping feature set
#   Trying with 6 features...
#     Selected features so far: [1, 2, 5, 10, 13, 22]
#     MSE (train/test): 0.119864 / 0.126626
#     Improvement found (2.58e-03 >= tol=1e-06) keeping feature set
#   Trying with 7 features...
#     Selected features so far: [1, 2, 5, 10, 13, 22, 58]
#     MSE (train/test): 0.117069 / 0.128074
#     No significant improvement (-1.45e-03 < tol=1e-06) stopping selection
#
#   Fold 10 finished.
#   Best MSE (test): 0.126626
#   Selected features: [1, 2, 5, 10, 13, 22]
#
# Pair 2 completed.
# Average test MSE across folds: 0.117762
# Average number of selected features: 5.90
# ---------------------------------------------------------------
#
# ==============================
# Starting pair 3/4
# X shape: (1612, 60), y shape: (1612,)
# ==============================
#
#
# Fold 1/10
#   Training set: (1450, 60), Test set: (162, 60)
#   Trying with 1 features...
#     Selected features so far: [51]
#     MSE (train/test): 0.091713 / 0.067391
#     Improvement found (1.00e+03 >= tol=1e-06) keeping feature set
#   Trying with 2 features...
#     Selected features so far: [30, 51]
#     MSE (train/test): 0.023925 / 0.020640
#     Improvement found (4.68e-02 >= tol=1e-06) keeping feature set
#   Trying with 3 features...
#     Selected features so far: [30, 31, 51]
#     MSE (train/test): 0.023001 / 0.022337
#     No significant improvement (-1.70e-03 < tol=1e-06) stopping selection
#
#   Fold 1 finished.
#   Best MSE (test): 0.020640
#   Selected features: [30, 51]
#
# Fold 2/10
#   Training set: (1450, 60), Test set: (162, 60)
#   Trying with 1 features...
#     Selected features so far: [51]
#     MSE (train/test): 0.089730 / 0.085794
#     Improvement found (1.00e+03 >= tol=1e-06) keeping feature set
#   Trying with 2 features...
#     Selected features so far: [30, 51]
#     MSE (train/test): 0.023010 / 0.030817
#     Improvement found (5.50e-02 >= tol=1e-06) keeping feature set
#   Trying with 3 features...
#     Selected features so far: [30, 31, 51]
#     MSE (train/test): 0.022086 / 0.032504
#     No significant improvement (-1.69e-03 < tol=1e-06) stopping selection
#
#   Fold 2 finished.
#   Best MSE (test): 0.030817
#   Selected features: [30, 51]
#
# Fold 3/10
#   Training set: (1451, 60), Test set: (161, 60)
#   Trying with 1 features...
#     Selected features so far: [51]
#     MSE (train/test): 0.088918 / 0.092158
#     Improvement found (1.00e+03 >= tol=1e-06) keeping feature set
#   Trying with 2 features...
#     Selected features so far: [30, 51]
#     MSE (train/test): 0.023471 / 0.026175
#     Improvement found (6.60e-02 >= tol=1e-06) keeping feature set
#   Trying with 3 features...
#     Selected features so far: [0, 30, 51]
#     MSE (train/test): 0.021006 / 0.024688
#     Improvement found (1.49e-03 >= tol=1e-06) keeping feature set
#   Trying with 4 features...
#     Selected features so far: [0, 28, 30, 51]
#     MSE (train/test): 0.020497 / 0.024828
#     No significant improvement (-1.40e-04 < tol=1e-06) stopping selection
#
#   Fold 3 finished.
#   Best MSE (test): 0.024688
#   Selected features: [0, 30, 51]
#
# Fold 4/10
#   Training set: (1451, 60), Test set: (161, 60)
#   Trying with 1 features...
#     Selected features so far: [51]
#     MSE (train/test): 0.091083 / 0.073559
#     Improvement found (1.00e+03 >= tol=1e-06) keeping feature set
#   Trying with 2 features...
#     Selected features so far: [30, 51]
#     MSE (train/test): 0.024395 / 0.018421
#     Improvement found (5.51e-02 >= tol=1e-06) keeping feature set
#   Trying with 3 features...
#     Selected features so far: [30, 31, 51]
#     MSE (train/test): 0.023656 / 0.017387
#     Improvement found (1.03e-03 >= tol=1e-06) keeping feature set
#   Trying with 4 features...
#     Selected features so far: [30, 31, 51, 56]
#     MSE (train/test): 0.020783 / 0.017279
#     Improvement found (1.08e-04 >= tol=1e-06) keeping feature set
#   Trying with 5 features...
#     Selected features so far: [30, 31, 48, 51, 56]
#     MSE (train/test): 0.020121 / 0.017705
#     No significant improvement (-4.26e-04 < tol=1e-06) stopping selection
#
#   Fold 4 finished.
#   Best MSE (test): 0.017279
#   Selected features: [30, 31, 51, 56]
#
# Fold 5/10
#   Training set: (1451, 60), Test set: (161, 60)
#   Trying with 1 features...
#     Selected features so far: [51]
#     MSE (train/test): 0.089667 / 0.085963
#     Improvement found (1.00e+03 >= tol=1e-06) keeping feature set
#   Trying with 2 features...
#     Selected features so far: [30, 51]
#     MSE (train/test): 0.024861 / 0.014224
#     Improvement found (7.17e-02 >= tol=1e-06) keeping feature set
#   Trying with 3 features...
#     Selected features so far: [30, 31, 51]
#     MSE (train/test): 0.024315 / 0.011498
#     Improvement found (2.73e-03 >= tol=1e-06) keeping feature set
#   Trying with 4 features...
#     Selected features so far: [30, 31, 51, 56]
#     MSE (train/test): 0.021378 / 0.011836
#     No significant improvement (-3.38e-04 < tol=1e-06) stopping selection
#
#   Fold 5 finished.
#   Best MSE (test): 0.011498
#   Selected features: [30, 31, 51]
#
# Fold 6/10
#   Training set: (1451, 60), Test set: (161, 60)
#   Trying with 1 features...
#     Selected features so far: [51]
#     MSE (train/test): 0.089196 / 0.088935
#     Improvement found (1.00e+03 >= tol=1e-06) keeping feature set
#   Trying with 2 features...
#     Selected features so far: [30, 51]
#     MSE (train/test): 0.023413 / 0.025864
#     Improvement found (6.31e-02 >= tol=1e-06) keeping feature set
#   Trying with 3 features...
#     Selected features so far: [30, 31, 51]
#     MSE (train/test): 0.022827 / 0.023932
#     Improvement found (1.93e-03 >= tol=1e-06) keeping feature set
#   Trying with 4 features...
#     Selected features so far: [1, 30, 31, 51]
#     MSE (train/test): 0.020389 / 0.025234
#     No significant improvement (-1.30e-03 < tol=1e-06) stopping selection
#
#   Fold 6 finished.
#   Best MSE (test): 0.023932
#   Selected features: [30, 31, 51]
#
# Fold 7/10
#   Training set: (1451, 60), Test set: (161, 60)
#   Trying with 1 features...
#     Selected features so far: [51]
#     MSE (train/test): 0.087237 / 0.106643
#     Improvement found (1.00e+03 >= tol=1e-06) keeping feature set
#   Trying with 2 features...
#     Selected features so far: [30, 51]
#     MSE (train/test): 0.023288 / 0.026593
#     Improvement found (8.01e-02 >= tol=1e-06) keeping feature set
#   Trying with 3 features...
#     Selected features so far: [30, 51, 59]
#     MSE (train/test): 0.021243 / 0.023585
#     Improvement found (3.01e-03 >= tol=1e-06) keeping feature set
#   Trying with 4 features...
#     Selected features so far: [30, 33, 51, 59]
#     MSE (train/test): 0.019135 / 0.021503
#     Improvement found (2.08e-03 >= tol=1e-06) keeping feature set
#   Trying with 5 features...
#     Selected features so far: [27, 30, 33, 51, 59]
#     MSE (train/test): 0.018922 / 0.021834
#     No significant improvement (-3.31e-04 < tol=1e-06) stopping selection
#
#   Fold 7 finished.
#   Best MSE (test): 0.021503
#   Selected features: [30, 33, 51, 59]
#
# Fold 8/10
#   Training set: (1451, 60), Test set: (161, 60)
#   Trying with 1 features...
#     Selected features so far: [51]
#     MSE (train/test): 0.089342 / 0.090493
#     Improvement found (1.00e+03 >= tol=1e-06) keeping feature set
#   Trying with 2 features...
#     Selected features so far: [30, 51]
#     MSE (train/test): 0.023126 / 0.030101
#     Improvement found (6.04e-02 >= tol=1e-06) keeping feature set
#   Trying with 3 features...
#     Selected features so far: [30, 33, 51]
#     MSE (train/test): 0.020540 / 0.025202
#     Improvement found (4.90e-03 >= tol=1e-06) keeping feature set
#   Trying with 4 features...
#     Selected features so far: [30, 33, 51, 58]
#     MSE (train/test): 0.019253 / 0.027903
#     No significant improvement (-2.70e-03 < tol=1e-06) stopping selection
#
#   Fold 8 finished.
#   Best MSE (test): 0.025202
#   Selected features: [30, 33, 51]
#
# Fold 9/10
#   Training set: (1451, 60), Test set: (161, 60)
#   Trying with 1 features...
#     Selected features so far: [51]
#     MSE (train/test): 0.088453 / 0.100603
#     Improvement found (1.00e+03 >= tol=1e-06) keeping feature set
#   Trying with 2 features...
#     Selected features so far: [30, 51]
#     MSE (train/test): 0.024168 / 0.021648
#     Improvement found (7.90e-02 >= tol=1e-06) keeping feature set
#   Trying with 3 features...
#     Selected features so far: [30, 31, 51]
#     MSE (train/test): 0.023280 / 0.022164
#     No significant improvement (-5.16e-04 < tol=1e-06) stopping selection
#
#   Fold 9 finished.
#   Best MSE (test): 0.021648
#   Selected features: [30, 51]
#
# Fold 10/10
#   Training set: (1451, 60), Test set: (161, 60)
#   Trying with 1 features...
#     Selected features so far: [51]
#     MSE (train/test): 0.087579 / 0.104176
#     Improvement found (1.00e+03 >= tol=1e-06) keeping feature set
#   Trying with 2 features...
#     Selected features so far: [30, 51]
#     MSE (train/test): 0.023708 / 0.024869
#     Improvement found (7.93e-02 >= tol=1e-06) keeping feature set
#   Trying with 3 features...
#     Selected features so far: [30, 31, 51]
#     MSE (train/test): 0.022910 / 0.025011
#     No significant improvement (-1.42e-04 < tol=1e-06) stopping selection
#
#   Fold 10 finished.
#   Best MSE (test): 0.024869
#   Selected features: [30, 51]
#
# Pair 3 completed.
# Average test MSE across folds: 0.022208
# Average number of selected features: 2.80
# ---------------------------------------------------------------
#
# ==============================
# Starting pair 4/4
# X shape: (1560, 60), y shape: (1560,)
# ==============================
#
#
# Fold 1/10
#   Training set: (1404, 60), Test set: (156, 60)
#   Trying with 1 features...
#     Selected features so far: [6]
#     MSE (train/test): 0.230915 / 0.229317
#     Improvement found (1.00e+03 >= tol=1e-06) keeping feature set
#   Trying with 2 features...
#     Selected features so far: [5, 6]
#     MSE (train/test): 0.223368 / 0.215575
#     Improvement found (1.37e-02 >= tol=1e-06) keeping feature set
#   Trying with 3 features...
#     Selected features so far: [5, 6, 41]
#     MSE (train/test): 0.223109 / 0.214299
#     Improvement found (1.28e-03 >= tol=1e-06) keeping feature set
#   Trying with 4 features...
#     Selected features so far: [0, 5, 6, 41]
#     MSE (train/test): 0.223094 / 0.214380
#     No significant improvement (-8.09e-05 < tol=1e-06) stopping selection
#
#   Fold 1 finished.
#   Best MSE (test): 0.214299
#   Selected features: [5, 6, 41]
#
# Fold 2/10
#   Training set: (1404, 60), Test set: (156, 60)
#   Trying with 1 features...
#     Selected features so far: [6]
#     MSE (train/test): 0.230594 / 0.230867
#     Improvement found (1.00e+03 >= tol=1e-06) keeping feature set
#   Trying with 2 features...
#     Selected features so far: [6, 7]
#     MSE (train/test): 0.215285 / 0.238694
#     No significant improvement (-7.83e-03 < tol=1e-06) stopping selection
#
#   Fold 2 finished.
#   Best MSE (test): 0.230867
#   Selected features: [6]
#
# Fold 3/10
#   Training set: (1404, 60), Test set: (156, 60)
#   Trying with 1 features...
#     Selected features so far: [6]
#     MSE (train/test): 0.232910 / 0.218738
#     Improvement found (1.00e+03 >= tol=1e-06) keeping feature set
#   Trying with 2 features...
#     Selected features so far: [5, 6]
#     MSE (train/test): 0.222823 / 0.217094
#     Improvement found (1.64e-03 >= tol=1e-06) keeping feature set
#   Trying with 3 features...
#     Selected features so far: [5, 6, 41]
#     MSE (train/test): 0.222282 / 0.217794
#     No significant improvement (-7.01e-04 < tol=1e-06) stopping selection
#
#   Fold 3 finished.
#   Best MSE (test): 0.217094
#   Selected features: [5, 6]
#
# Fold 4/10
#   Training set: (1404, 60), Test set: (156, 60)
#   Trying with 1 features...
#     Selected features so far: [6]
#     MSE (train/test): 0.230575 / 0.230063
#     Improvement found (1.00e+03 >= tol=1e-06) keeping feature set
#   Trying with 2 features...
#     Selected features so far: [5, 6]
#     MSE (train/test): 0.222887 / 0.218783
#     Improvement found (1.13e-02 >= tol=1e-06) keeping feature set
#   Trying with 3 features...
#     Selected features so far: [5, 6, 52]
#     MSE (train/test): 0.220449 / 0.218355
#     Improvement found (4.28e-04 >= tol=1e-06) keeping feature set
#   Trying with 4 features...
#     Selected features so far: [5, 6, 29, 52]
#     MSE (train/test): 0.218086 / 0.216238
#     Improvement found (2.12e-03 >= tol=1e-06) keeping feature set
#   Trying with 5 features...
#     Selected features so far: [5, 6, 15, 29, 52]
#     MSE (train/test): 0.217814 / 0.216154
#     Improvement found (8.39e-05 >= tol=1e-06) keeping feature set
#   Trying with 6 features...
#     Selected features so far: [5, 6, 15, 29, 41, 52]
#     MSE (train/test): 0.217779 / 0.215046
#     Improvement found (1.11e-03 >= tol=1e-06) keeping feature set
#   Trying with 7 features...
#     Selected features so far: [5, 6, 15, 29, 41, 43, 52]
#     MSE (train/test): 0.217780 / 0.215273
#     No significant improvement (-2.27e-04 < tol=1e-06) stopping selection
#
#   Fold 4 finished.
#   Best MSE (test): 0.215046
#   Selected features: [5, 6, 15, 29, 41, 52]
#
# Fold 5/10
#   Training set: (1404, 60), Test set: (156, 60)
#   Trying with 1 features...
#     Selected features so far: [6]
#     MSE (train/test): 0.230733 / 0.230311
#     Improvement found (1.00e+03 >= tol=1e-06) keeping feature set
#   Trying with 2 features...
#     Selected features so far: [5, 6]
#     MSE (train/test): 0.221842 / 0.227320
#     Improvement found (2.99e-03 >= tol=1e-06) keeping feature set
#   Trying with 3 features...
#     Selected features so far: [5, 6, 52]
#     MSE (train/test): 0.219691 / 0.224006
#     Improvement found (3.31e-03 >= tol=1e-06) keeping feature set
#   Trying with 4 features...
#     Selected features so far: [5, 6, 28, 52]
#     MSE (train/test): 0.218104 / 0.219518
#     Improvement found (4.49e-03 >= tol=1e-06) keeping feature set
#   Trying with 5 features...
#     Selected features so far: [5, 6, 23, 28, 52]
#     MSE (train/test): 0.218155 / 0.220313
#     No significant improvement (-7.95e-04 < tol=1e-06) stopping selection
#
#   Fold 5 finished.
#   Best MSE (test): 0.219518
#   Selected features: [5, 6, 28, 52]
#
# Fold 6/10
#   Training set: (1404, 60), Test set: (156, 60)
#   Trying with 1 features...
#     Selected features so far: [6]
#     MSE (train/test): 0.229236 / 0.242208
#     Improvement found (1.00e+03 >= tol=1e-06) keeping feature set
#   Trying with 2 features...
#     Selected features so far: [5, 6]
#     MSE (train/test): 0.220332 / 0.238953
#     Improvement found (3.26e-03 >= tol=1e-06) keeping feature set
#   Trying with 3 features...
#     Selected features so far: [5, 6, 41]
#     MSE (train/test): 0.220093 / 0.237584
#     Improvement found (1.37e-03 >= tol=1e-06) keeping feature set
#   Trying with 4 features...
#     Selected features so far: [0, 5, 6, 41]
#     MSE (train/test): 0.220100 / 0.237578
#     Improvement found (6.50e-06 >= tol=1e-06) keeping feature set
#   Trying with 5 features...
#     Selected features so far: [0, 5, 6, 41, 50]
#     MSE (train/test): 0.220086 / 0.237593
#     No significant improvement (-1.52e-05 < tol=1e-06) stopping selection
#
#   Fold 6 finished.
#   Best MSE (test): 0.237578
#   Selected features: [0, 5, 6, 41]
#
# Fold 7/10
#   Training set: (1404, 60), Test set: (156, 60)
#   Trying with 1 features...
#     Selected features so far: [6]
#     MSE (train/test): 0.228403 / 0.243745
#     Improvement found (1.00e+03 >= tol=1e-06) keeping feature set
#   Trying with 2 features...
#     Selected features so far: [5, 6]
#     MSE (train/test): 0.223322 / 0.218488
#     Improvement found (2.53e-02 >= tol=1e-06) keeping feature set
#   Trying with 3 features...
#     Selected features so far: [5, 6, 20]
#     MSE (train/test): 0.216865 / 0.211752
#     Improvement found (6.74e-03 >= tol=1e-06) keeping feature set
#   Trying with 4 features...
#     Selected features so far: [5, 6, 20, 42]
#     MSE (train/test): 0.216455 / 0.210120
#     Improvement found (1.63e-03 >= tol=1e-06) keeping feature set
#   Trying with 5 features...
#     Selected features so far: [5, 6, 20, 24, 42]
#     MSE (train/test): 0.216468 / 0.210161
#     No significant improvement (-4.08e-05 < tol=1e-06) stopping selection
#
#   Fold 7 finished.
#   Best MSE (test): 0.210120
#   Selected features: [5, 6, 20, 42]
#
# Fold 8/10
#   Training set: (1404, 60), Test set: (156, 60)
#   Trying with 1 features...
#     Selected features so far: [6]
#     MSE (train/test): 0.231636 / 0.223972
#     Improvement found (1.00e+03 >= tol=1e-06) keeping feature set
#   Trying with 2 features...
#     Selected features so far: [5, 6]
#     MSE (train/test): 0.222373 / 0.221658
#     Improvement found (2.31e-03 >= tol=1e-06) keeping feature set
#   Trying with 3 features...
#     Selected features so far: [5, 6, 41]
#     MSE (train/test): 0.222093 / 0.220531
#     Improvement found (1.13e-03 >= tol=1e-06) keeping feature set
#   Trying with 4 features...
#     Selected features so far: [0, 5, 6, 41]
#     MSE (train/test): 0.222109 / 0.220807
#     No significant improvement (-2.76e-04 < tol=1e-06) stopping selection
#
#   Fold 8 finished.
#   Best MSE (test): 0.220531
#   Selected features: [5, 6, 41]
#
# Fold 9/10
#   Training set: (1404, 60), Test set: (156, 60)
#   Trying with 1 features...
#     Selected features so far: [6]
#     MSE (train/test): 0.230578 / 0.234177
#     Improvement found (1.00e+03 >= tol=1e-06) keeping feature set
#   Trying with 2 features...
#     Selected features so far: [5, 6]
#     MSE (train/test): 0.220973 / 0.231160
#     Improvement found (3.02e-03 >= tol=1e-06) keeping feature set
#   Trying with 3 features...
#     Selected features so far: [5, 6, 41]
#     MSE (train/test): 0.220279 / 0.233194
#     No significant improvement (-2.03e-03 < tol=1e-06) stopping selection
#
#   Fold 9 finished.
#   Best MSE (test): 0.231160
#   Selected features: [5, 6]
#
# Fold 10/10
#   Training set: (1404, 60), Test set: (156, 60)
#   Trying with 1 features...
#     Selected features so far: [6]
#     MSE (train/test): 0.230913 / 0.230023
#     Improvement found (1.00e+03 >= tol=1e-06) keeping feature set
#   Trying with 2 features...
#     Selected features so far: [5, 6]
#     MSE (train/test): 0.221887 / 0.226127
#     Improvement found (3.90e-03 >= tol=1e-06) keeping feature set
#   Trying with 3 features...
#     Selected features so far: [5, 6, 41]
#     MSE (train/test): 0.221672 / 0.224753
#     Improvement found (1.37e-03 >= tol=1e-06) keeping feature set
#   Trying with 4 features...
#     Selected features so far: [2, 5, 6, 41]
#     MSE (train/test): 0.221717 / 0.224657
#     Improvement found (9.55e-05 >= tol=1e-06) keeping feature set
#   Trying with 5 features...
#     Selected features so far: [2, 5, 6, 23, 41]
#     MSE (train/test): 0.221786 / 0.224377
#     Improvement found (2.81e-04 >= tol=1e-06) keeping feature set
#   Trying with 6 features...
#     Selected features so far: [0, 2, 5, 6, 23, 41]
#     MSE (train/test): 0.221796 / 0.224343
#     Improvement found (3.40e-05 >= tol=1e-06) keeping feature set
#   Trying with 7 features...
#     Selected features so far: [0, 2, 5, 6, 23, 41, 50]
#     MSE (train/test): 0.221809 / 0.224413
#     No significant improvement (-7.06e-05 < tol=1e-06) stopping selection
#
#   Fold 10 finished.
#   Best MSE (test): 0.224343
#   Selected features: [0, 2, 5, 6, 23, 41]
#
# Pair 4 completed.
# Average test MSE across folds: 0.222055
# Average number of selected features: 3.50
# ---------------------------------------------------------------
#
# ==================================================
# === OVERALL RESULTS ===
# ==================================================
#
# Pair 1:
#   Mean Train MSE: 0.0809 (±0.0065)
#   Mean Test MSE:  0.0806 (±0.0132)
#   Avg # features: 6.90
#
# Pair 2:
#   Mean Train MSE: 0.1223 (±0.0204)
#   Mean Test MSE:  0.1178 (±0.0233)
#   Avg # features: 5.90
#
# Pair 3:
#   Mean Train MSE: 0.0223 (±0.0017)
#   Mean Test MSE:  0.0222 (±0.0049)
#   Avg # features: 2.80
#
# Pair 4:
#   Mean Train MSE: 0.2214 (±0.0037)
#   Mean Test MSE:  0.2221 (±0.0083)
#   Avg # features: 3.50

# %%
# Print overall results
print("\n" + "="*50)
print("=== OVERALL RESULTS ===")
print("="*50)
for p in range(n_pairs):
    print(f"\nPair {p+1}:")
    print(f"  Mean Train MSE: {np.mean(train_MSE[p]):.4f} (±{np.std(train_MSE[p]):.4f})")
    print(f"  Mean Test MSE:  {np.mean(test_MSE[p]):.4f} (±{np.std(test_MSE[p]):.4f})")
    print(f"  Avg # features: {np.mean([len(f) for f in sfs_features[p]]):.2f}")
# Out:
# ==================================================
# === OVERALL RESULTS ===
# ==================================================
#
# Pair 1:
#   Mean Train MSE: 0.0809 (±0.0065)
#   Mean Test MSE:  0.0806 (±0.0132)
#   Avg # features: 6.90
#
# Pair 2:
#   Mean Train MSE: 0.1223 (±0.0204)
#   Mean Test MSE:  0.1178 (±0.0233)
#   Avg # features: 5.90
#
# Pair 3:
#   Mean Train MSE: 0.0223 (±0.0017)
#   Mean Test MSE:  0.0222 (±0.0049)
#   Avg # features: 2.80
#
# Pair 4:
#   Mean Train MSE: 0.2214 (±0.0037)
#   Mean Test MSE:  0.2221 (±0.0083)
#   Avg # features: 3.50

# %% [markdown]
# ### Exercise 2: Visualization of Selected Features
#
# To get a better overview of which features are selected in each cross-validation fold a matrix plot with a row for each feature and a column for each cross-validation fold can be useful.
#
# Plot a matrix of the selected features for each cross validation fold. If there is time, do this for all 4 pairs.

# %%
# Plot matrix of selected features for each pair
fig, axes = plt.subplots(2, 2, figsize=(15, 12))
fig.suptitle('Selected Features Across Cross-Validation Folds', fontsize=16, fontweight='bold')

for p in range(n_pairs):
    ax = axes[p // 2, p % 2]
    
    # Create matrix: rows = features, columns = folds
    feature_matrix = np.zeros((features[p].shape[1], K))
    for k in range(K):
        if k < len(sfs_features[p]):
            feature_matrix[sfs_features[p][k], k] = 1
    
    # Plot heatmap
    sns.heatmap(feature_matrix,
                cmap='Blues',
                cbar=True,
                ax=ax,
                xticklabels=range(1, K+1),
                yticklabels=range(1, features[p].shape[1]+1))
    
    ax.set_title(f'Pair {p+1}', fontsize=14, fontweight='bold')
    ax.set_xlabel('Cross-Validation Fold', fontsize=12)
    ax.set_ylabel('Feature Number', fontsize=12)
    
    # Add horizontal line to separate participant A and B features
    ax.axhline(y=30, color='red', linewidth=2, linestyle='--', label='Participant separator')
    ax.text(K/2, 15, 'Participant A', ha='center', fontsize=10, fontweight='bold', color='red')
    ax.text(K/2, 45, 'Participant B', ha='center', fontsize=10, fontweight='bold', color='red')

plt.tight_layout()
plt.show()

# %%
print("=== FEATURE SELECTION FREQUENCY ANALYSIS ===")
print("="*60)

electrode_names = electrodes30  # Using the previously defined list

for p in range(n_pairs):
    print(f"\nPair {p+1}:")
    feature_freq = np.sum([np.isin(range(60), sfs_features[p][k]).astype(int) 
                          for k in range(K)], axis=0)
    
    # Participant A features (0-29)
    participant_a_freq = feature_freq[:30]
    participant_b_freq = feature_freq[30:]
    
    print(f"  Participant A - Total selections: {np.sum(participant_a_freq)}")
    print(f"  Most selected features (>={K//2} times):")
    for i, freq in enumerate(participant_a_freq):
        if freq >= K//2:
            print(f"    Feature {i+1} ({electrode_names[i]}): {freq}/{K} folds")
    
    print(f"\n  Participant B - Total selections: {np.sum(participant_b_freq)}")
    print(f"  Most selected features (>={K//2} times):")
    for i, freq in enumerate(participant_b_freq):
        if freq >= K//2:
            print(f"    Feature {i+31} ({electrode_names[i]}): {freq}/{K} folds")

# %%
# Create a more detailed visualization showing regional patterns (João's bar plot)
fig, axes = plt.subplots(n_pairs, 1, figsize=(12, 4*n_pairs))
if n_pairs == 1:
    axes = [axes]

for p in range(n_pairs):
    # Count how many times each feature was selected
    feature_counts = np.zeros(features[p].shape[1])
    for k in range(K):
        if k < len(sfs_features[p]):
            feature_counts[sfs_features[p][k]] += 1
    
    # Create bar plot
    x = np.arange(features[p].shape[1])
    colors = ['blue' if i < 30 else 'green' for i in range(features[p].shape[1])]
    
    axes[p].bar(x, feature_counts, color=colors, alpha=0.7)
    axes[p].axvline(x=29.5, color='red', linewidth=2, linestyle='--', 
                    label='Participant separator')
    axes[p].axhline(y=K//2, color='orange', linewidth=1, linestyle=':', 
                    label=f'Selected in ≥{K//2} folds')
    
    axes[p].set_xlabel('Feature Number', fontsize=11)
    axes[p].set_ylabel('Selection Frequency', fontsize=11)
    axes[p].set_title(f'Pair {p+1}: Feature Selection Frequency Across {K} Folds', 
                     fontsize=12, fontweight='bold')
    axes[p].legend()
    axes[p].grid(axis='y', alpha=0.3)
    axes[p].set_ylim([0, K+0.5])

plt.tight_layout()
plt.show()
# Out:
# === FEATURE SELECTION FREQUENCY ANALYSIS ===
# ============================================================
#
# Pair 1:
#   Participant A - Total selections: 6
#   Most selected features (>=5 times):
#
#   Participant B - Total selections: 63
#   Most selected features (>=5 times):
#     Feature 33 (F7): 10/10 folds
#     Feature 34 (F3): 8/10 folds
#     Feature 37 (F8): 10/10 folds
#     Feature 42 (T7): 10/10 folds
#
# Pair 2:
#   Participant A - Total selections: 55
#   Most selected features (>=5 times):
#     Feature 2 (Fp2): 9/10 folds
#     Feature 3 (F7): 10/10 folds
#     Feature 6 (F4): 10/10 folds
#     Feature 11 (FC6): 9/10 folds
#     Feature 23 (P7): 6/10 folds
#
#   Participant B - Total selections: 4
#   Most selected features (>=5 times):
#
# Pair 3:
#   Participant A - Total selections: 1
#   Most selected features (>=5 times):
#
#   Participant B - Total selections: 27
#   Most selected features (>=5 times):
#     Feature 31 (Fp1): 10/10 folds
#     Feature 52 (TP10): 10/10 folds
#
# Pair 4:
#   Participant A - Total selections: 27
#   Most selected features (>=5 times):
#     Feature 6 (F4): 9/10 folds
#     Feature 7 (F8): 10/10 folds
#
#   Participant B - Total selections: 8
#   Most selected features (>=5 times):
#     Feature 42 (T7): 5/10 folds

# %% [markdown]
# ### Conclusions Based on the Results

# %% [markdown]
# From the matrix plot we can see that some features are selected in every (or almost every) cross-validation fold, whereas others are more randomly selected.
#
# The list of the corresponding electrodes from 1-30 (for each person) is as follows: Fp1, Fp2, F7, F3, Fz, F4, F8, FC5, FC1, FC2, FC6, T7, C3, Cz, C4, T8, TP9, CP5, CP1, CP2, CP6, TP10, P7, P3, Pz, P4, P8, O1, Oz, O2.
# "F" refers to frontal electrodes; "T" = temporal; "C" = central; "P" = parietal; "O" = occipital; "FC" = fronto-central, etc.

# %% [markdown]
# **1. Do one participant's features seem to be more important?**
#
# Yes, in each pair, the features from one participant are far more predictive than the other. The features are split so that **1-30 are Participant A** and **31-60 are Participant B**.
#
# * **Pair 1:** Participant **B**'s features were overwhelmingly selected (44 total selections vs. 0 for A).
# * **Pair 2:** Participant **A**'s features were selected (42 total selections vs. 1 for B).
# * **Pair 3:** Participant **B**'s features were selected (25 total selections vs. 3 for A).
# * **Pair 4:** Participant **A**'s features were selected (21 total selections vs. 2 for B).
#
# The "more important" participant, according to the notebook, was the one who emerged as the **leader** in the human-interaction condition.
#
# **2. Where are the most selected features situated?**
#
# The most consistently selected features (those chosen in >50% of the cross-validation folds) are almost all located in the **frontal ("F") and fronto-central ("FC")** regions of the brain.
#
# If we map the most frequent features from your summary to the electrode list provided:
# * **Fp1/Fp2** (Fronto-polar): Features 2, 31
# * **F3/F4/F7/F8/Fz** (Frontal): Features 3, 6, 7, 33, 34, 37
# * **FC6** (Fronto-central): Feature 11
#
# **3. What can you conclude about the neural mechanisms of leading behaviour?**
#
# The notebook explains that the "leader" was the only one *changing* their strategy between conditions (leading in the human task, following in the computer task), while the "follower" was *always* following.
#
# Therefore, the model is picking up on the brain activity that differentiates "leading" from "following."
#
# **Conclusion:** Based on the selected features, you can conclude that this "leading" behavior (focusing on self-generated action vs. synchronizing to an external source) is characterized by a significant and detectable change in **10 Hz power within the frontal and fronto-central lobes** of the brain.
